# %%
import xarray as xr

# %%
data_path = '/nfs/gce/projects/crocus/data/ingested-data/ai-dt/crocus_micronet_merged_202505.v1.nc'

# %%
ds = xr.open_dataset(data_path)
ds
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:        (site: 11, time: 744)
# Coordinates:
#   * time           (time) datetime64[ns] 6kB 2025-05-01 ... 2025-05-31T23:00:00
#   * site           (site) <U5 220B 'NU' 'CSU' 'NEIU' ... 'DOWN' 'SHEDD' 'VILLA'
#     local_time     (time) datetime64[ns] 6kB ...
# Data variables: (12/19)
#     temperature    (site, time) float64 65kB ...
#     humidity       (site, time) float64 65kB ...
#     pressure       (site, time) float64 65kB ...
#     rainfall       (site, time) float64 65kB ...
#     dewpoint       (site, time) float64 65kB ...
#     wetbulb        (site, time) float64 65kB ...
#     ...             ...
#     o3             (site, time) float64 65kB ...
#     no2            (site, time) float64 65kB ...
#     co             (site, time) float64 65kB ...
#     latitude       (site) float64 88B ...
#     longitude      (site) float64 88B ...
#     wsn            (site) <U4 176B ...
# Attributes:
#     convention:         CF 1.10
# ...

# %%
ds.sel(site="HUM")["wind_max_10s"].plot()
